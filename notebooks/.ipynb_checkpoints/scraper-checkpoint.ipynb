# %%
from bs4 import BeautifulSoup
import json
from selenium import webdriver

# %%
def get_live(sport='basketball'):
    url = 'https://sports.bovada.lv/{}'.format(sport)
    driver = webdriver.Chrome('../chromedriver')
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    js = soup.find_all('script', {'class': 'content-data'})[0]
    live_data = re.findall('\[(.+)\]', str(js))[0]
    live_data = json.loads(live_data)
    return live_data

# %%
url = 'https://sports.bovada.lv/basketball'

# %%
driver = webdriver.Chrome('../chromedriver')
driver.get(url)

# %%
get_live()
# Out:
# {u'card_data': {u'items': [{u'itemList': {u'items': [{u'LIVE': True,
#        u'atmosphereLink': u'/api/atmosphere/eventNotification/events/A/3230223',
#        u'awayTeamFirst': True,
#        u'baseLink': u'/basketball/europe/portugal/lpb/fc-porto-benfica-lisboa-201805271200',
#        u'competitionId': u'2702019',
#        u'competitors': [{u'abbreviation': u'BEN',
#          u'description': u'Benfica Lisboa',
#          u'id': u'3230223-1018',
#          u'shortName': u'Benfica',
#          u'type': u'HOME'},
#         {u'abbreviation': u'FCP',
#          u'description': u'FC Porto',
#          u'id': u'3230223-6179784',
#          u'shortName': u'FC Porto',
#          u'type': u'AWAY'}],
#        u'denySameGame': u'NO',
#        u'description': u'FC Porto @ Benfica Lisboa',
#        u'displayGroups': [{u'baseLink': u'/basketball/europe/portugal/lpb/game-lines-market-group',
#          u'defaultType': True,
#          u'description': u'Game Lines',
#          u'id': u'97',
# ...

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, 'lxml')

# %%
js = soup.find_all('script', {'class': 'content-data'})[0]

# %%
data = re.findall('\[(.+)\]', str(js))[0]

# %%
live_data = json.loads(data)

# %%
pd.DataFrame(live_data)
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# <ipython-input-82-ea0d96798f88> in <module>()
# ----> 1 pd.DataFrame(live_data['card_data']['itemList'])
#
# KeyError: 'itemList'

# %%
live_data['card_data']['items'][0]['itemList']['items']
# Out:
# [{u'LIVE': True,
#   u'atmosphereLink': u'/api/atmosphere/eventNotification/events/A/3230223',
#   u'awayTeamFirst': True,
#   u'baseLink': u'/basketball/europe/portugal/lpb/fc-porto-benfica-lisboa-201805271200',
#   u'competitionId': u'2702019',
#   u'competitors': [{u'abbreviation': u'BEN',
#     u'description': u'Benfica Lisboa',
#     u'id': u'3230223-1018',
#     u'shortName': u'Benfica',
#     u'type': u'HOME'},
#    {u'abbreviation': u'FCP',
#     u'description': u'FC Porto',
#     u'id': u'3230223-6179784',
#     u'shortName': u'FC Porto',
#     u'type': u'AWAY'}],
#   u'denySameGame': u'NO',
#   u'description': u'FC Porto @ Benfica Lisboa',
#   u'displayGroups': [{u'baseLink': u'/basketball/europe/portugal/lpb/game-lines-market-group',
#     u'defaultType': True,
#     u'description': u'Game Lines',
#     u'id': u'97',
#     u'itemList': [{u'belongsToDefault': True,
#       u'columns': u'H2Columns',
#       u'description': u'Point Spread',
# ...

# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://admin:<dbpassword>@ds235840.mlab.com:35840/odds')
